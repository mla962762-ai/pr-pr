# %% [markdown]
# <a href="https://colab.research.google.com/github/mla962762-ai/pr-pr/blob/main/project%20python0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

limit = 30
skip = 0
all_pages = []

while True:
    url = f"https://dummyjson.com/users?limit={limit}&skip={skip}"
    response = requests.get(url)
    response.raise_for_status()

    data = response.json()
    users = data["users"]


    if not users:
        break

    df_page = pd.json_normalize(users)
    all_pages.append(df_page)

    skip += limit

df = pd.concat(all_pages, ignore_index=True)
print(df)
df.to_csv("users.csv", index=False)
print("Saved to users.xlsx")
# Out:
#       id firstName  lastName maidenName  age  gender  \
# 0      1     Emily   Johnson      Smith   29  female
# 1      2   Michael  Williams              36    male
# 2      3    Sophia     Brown              43  female
# 3      4     James     Davis              46    male
# 4      5      Emma    Miller    Johnson   31  female
# ..   ...       ...       ...        ...  ...     ...
# 203  204     Mateo     Perez              46    male
# 204  205    Aubrey    Garcia       Gray   29  female
# 205  206     Elena     Baker              35  female
# 206  207      Jace     Smith              42    male
# 207  208  Samantha  Martinez      Lopez   28  female
#
#                                  email             phone   username  \
# 0        emily.johnson@x.dummyjson.com  +81 965-431-3024     emilys
# 1     michael.williams@x.dummyjson.com  +49 258-627-6644   michaelw
# 2         sophia.brown@x.dummyjson.com  +81 210-652-2785    sophiab
# 3          james.davis@x.dummyjson.com  +49 614-958-9364     jamesd
# 4          emma.miller@x.dummyjson.com  +91 759-776-1614      emmaj
# ..                                 ...               ...        ...
# 203        mateo.perez@x.dummyjson.com  +44 704-302-8113     mateop
# 204      aubrey.garcia@x.dummyjson.com   +1 470-576-9130    aubreyg
# 205        elena.baker@x.dummyjson.com  +49 978-346-6960     elenab
# 206         jace.smith@x.dummyjson.com   +1 634-923-7779      jaces
# 207  samantha.martinez@x.dummyjson.com  +49 493-402-2473  samanthal
#
#           password  ... company.address.city company.address.state  \
# 0       emilyspass  ...        San Francisco             Wisconsin
# 1     michaelwpass  ...          Los Angeles         New Hampshire
# 2      sophiabpass  ...               Dallas                Nevada
# 3       jamesdpass  ...           Fort Worth          Pennsylvania
# 4        emmajpass  ...          San Antonio                 Idaho
# ..             ...  ...                  ...                   ...
# 203     mateoppass  ...               Denver               Arizona
# 204    aubreygpass  ...        San Francisco             Minnesota
# 205     elenabpass  ...          San Antonio                 Idaho
# 206      jacespass  ...        San Francisco               Arizona
# 207  samanthalpass  ...            San Diego         Massachusetts
#
#     company.address.stateCode  company.address.postalCode  \
# 0                          WI                       37657
# 1                          NH                       73442
# 2                          NV                       88511
# 3                          PA                       27768
# 4                          ID                       21965
# ..                        ...                         ...
# 203                        AZ                       10591
# 204                        MN                       58649
# 205                        ID                       50546
# 206                        AZ                       19079
# 207                        MA                       75183
#
#      company.address.coordinates.lat company.address.coordinates.lng  \
# 0                          71.814525                     -161.150263
# 1                          79.098326                     -119.624845
# 2                          20.086743                      -34.577107
# 3                          54.911930                      -79.498328
# 4                          44.346545                      -26.944701
# ..                               ...                             ...
# 203                        18.569908                      -50.337520
# 204                         3.609112                      -35.397672
# 205                         1.356153                      175.897893
# 206                         2.230209                       84.272010
# 207                       -43.398744                     -176.705236
#
#     company.address.country crypto.coin  \
# 0             United States     Bitcoin
# 1             United States     Bitcoin
# 2             United States     Bitcoin
# 3             United States     Bitcoin
# 4             United States     Bitcoin
# ..                      ...         ...
# 203           United States     Bitcoin
# 204           United States     Bitcoin
# 205           United States     Bitcoin
# 206           United States     Bitcoin
# 207           United States     Bitcoin
#
#                                   crypto.wallet    crypto.network
# 0    0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 1    0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 2    0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 3    0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 4    0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# ..                                          ...               ...
# 203  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 204  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 205  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 206  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 207  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
#
# [208 rows x 52 columns]
# Saved to users.xlsx

# %%
# Read data from csv file
df =pd.read_csv("users.csv")

# %%
df.shape
# Out:
# (208, 52)

# %%
df.columns.tolist()
# Out:
# ['id',
#  'firstName',
#  'lastName',
#  'maidenName',
#  'age',
#  'gender',
#  'email',
#  'phone',
#  'username',
#  'password',
#  'birthDate',
#  'image',
#  'bloodGroup',
#  'height',
#  'weight',
#  'eyeColor',
#  'ip',
#  'macAddress',
#  'university',
#  'ein',
#  'ssn',
#  'userAgent',
#  'role',
#  'hair.color',
#  'hair.type',
#  'address.address',
#  'address.city',
#  'address.state',
#  'address.stateCode',
#  'address.postalCode',
#  'address.coordinates.lat',
#  'address.coordinates.lng',
#  'address.country',
#  'bank.cardExpire',
#  'bank.cardNumber',
#  'bank.cardType',
#  'bank.currency',
#  'bank.iban',
#  'company.department',
#  'company.name',
#  'company.title',
#  'company.address.address',
#  'company.address.city',
#  'company.address.state',
#  'company.address.stateCode',
#  'company.address.postalCode',
#  'company.address.coordinates.lat',
#  'company.address.coordinates.lng',
#  'company.address.country',
#  'crypto.coin',
#  'crypto.wallet',
#  'crypto.network']

# %%
df.dtypes
# Out:
# id                                   int64
# firstName                           object
# lastName                            object
# maidenName                          object
# age                                  int64
# gender                              object
# email                               object
# phone                               object
# username                            object
# password                            object
# birthDate                           object
# image                               object
# bloodGroup                          object
# height                             float64
# weight                             float64
# eyeColor                            object
# ip                                  object
# macAddress                          object
# university                          object
# ein                                 object
# ssn                                 object
# userAgent                           object
# role                                object
# hair.color                          object
# hair.type                           object
# address.address                     object
# address.city                        object
# address.state                       object
# address.stateCode                   object
# address.postalCode                   int64
# address.coordinates.lat            float64
# address.coordinates.lng            float64
# address.country                     object
# bank.cardExpire                     object
# bank.cardNumber                      int64
# bank.cardType                       object
# bank.currency                       object
# bank.iban                           object
# company.department                  object
# company.name                        object
# company.title                       object
# company.address.address             object
# company.address.city                object
# company.address.state               object
# company.address.stateCode           object
# company.address.postalCode           int64
# company.address.coordinates.lat    float64
# company.address.coordinates.lng    float64
# company.address.country             object
# crypto.coin                         object
# crypto.wallet                       object
# crypto.network                      object
# dtype: object

# %%
# Number of missing values per column
df.isnull().sum().sort_values(ascending=True)
# Out:
# id                                   0
# firstName                            0
# lastName                             0
# age                                  0
# email                                0
# gender                               0
# phone                                0
# username                             0
# bloodGroup                           0
# password                             0
# birthDate                            0
# image                                0
# weight                               0
# height                               0
# eyeColor                             0
# ip                                   0
# hair.type                            0
# macAddress                           0
# university                           0
# ein                                  0
# ssn                                  0
# userAgent                            0
# role                                 0
# hair.color                           0
# address.stateCode                    0
# address.address                      0
# address.city                         0
# address.state                        0
# address.coordinates.lat              0
# address.postalCode                   0
# address.coordinates.lng              0
# address.country                      0
# company.address.country              0
# bank.cardExpire                      0
# bank.cardNumber                      0
# bank.cardType                        0
# bank.currency                        0
# bank.iban                            0
# company.department                   0
# company.name                         0
# company.title                        0
# company.address.address              0
# company.address.city                 0
# company.address.state                0
# company.address.stateCode            0
# company.address.postalCode           0
# company.address.coordinates.lat      0
# company.address.coordinates.lng      0
# crypto.wallet                        0
# crypto.coin                          0
# crypto.network                       0
# maidenName                         148
# dtype: int64

# %%
# Number of duplicate rows
x=df.duplicated().sum()
print(x)
# Out:
# 0

# %%
# Summary statistics for numeric columns
df.describe()
# Out:
#                id         age      height      weight  address.postalCode  \
# count  208.000000  208.000000  208.000000  208.000000          208.000000
# mean   104.500000   33.139423  175.720240   75.038606        49476.177885
# std     60.188592    5.544269   14.119984   14.090775        21838.772935
# min      1.000000   23.000000  150.250000   50.100000        10672.000000
# 25%     52.750000   29.000000  164.187500   62.547500        31945.750000
# 50%    104.500000   32.000000  177.430000   75.985000        49007.500000
# 75%    156.250000   36.000000  186.960000   86.992500        65612.500000
# max    208.000000   46.000000  199.810000   99.540000        89729.000000
#
#        address.coordinates.lat  address.coordinates.lng  bank.cardNumber  \
# count               208.000000               208.000000     2.080000e+02
# mean                 -0.357609               -11.729826     4.352591e+15
# std                  53.866250               103.855891     1.871526e+15
# min                 -89.077500              -179.958549     3.407609e+14
# 25%                 -52.583475              -101.197683     3.608283e+15
# 50%                   2.925385               -29.607807     4.940431e+15
# 75%                  45.281022                71.862635     6.011151e+15
# max                  89.781211               179.922909     6.293711e+15
#
#        company.address.postalCode  company.address.coordinates.lat  \
# count                  208.000000                       208.000000
# mean                 51994.442308                         2.267603
# std                  23329.345011                        50.015813
# min                  10371.000000                       -87.103718
# 25%                  30837.500000                       -40.780079
# 50%                  55624.500000                         7.324804
# 75%                  72775.750000                        43.829917
# max                  89416.000000                        89.270633
#
#        company.address.coordinates.lng
# count                       208.000000
# mean                         -2.701298
# std                          99.876659
# min                        -176.705236
# 25%                         -83.301244
# 50%                          -6.090248
# 75%                          84.288805
# max                         178.804291

# %%
df["gender"].value_counts()
# Out:
# gender
# female    106
# male      102
# Name: count, dtype: int64

# %%
df["bloodGroup"].value_counts()
# Out:
# bloodGroup
# O-     31
# B-     31
# AB-    29
# AB+    29
# B+     25
# O+     22
# A+     21
# A-     20
# Name: count, dtype: int64

# %%
df["eyeColor"].value_counts()
# Out:
# eyeColor
# Brown     35
# Hazel     34
# Green     28
# Blue      24
# Gray      24
# Violet    22
# Red       21
# Amber     20
# Name: count, dtype: int64

# %%
df["role"].value_counts()
# Out:
# role
# user         193
# moderator     10
# admin          5
# Name: count, dtype: int64

# %%
df["address.country"].value_counts()
# Out:
# address.country
# United States    208
# Name: count, dtype: int64

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
df["maidenName"].value_counts()
# Out:
# maidenName
# Adams        4
# Brown        3
# Hernandez    3
# Evans        3
# Martin       2
# Baker        2
# Johnson      2
# Taylor       2
# Perez        2
# Ward         2
# Bell         2
# Flores       2
# Lopez        2
# Mitchell     2
# Gomez        2
# Martinez     1
# Clark        1
# Smith        1
# Davis        1
# Rodriguez    1
# Thomas       1
# White        1
# Moore        1
# Harris       1
# Graham       1
# Kelly        1
# Morgan       1
# Carter       1
# Price        1
# Gonzalez     1
# Miller       1
# Robinson     1
# Foster       1
# Stewart      1
# Sanchez      1
# Nelson       1
# Hill         1
# Wright       1
# Collins      1
# Gray         1
# Name: count, dtype: int64

# %%
df.drop("maidenName", axis=1, inplace=True)
df.tail(5)
# Out:
#       id firstName  lastName  age  gender                              email  \
# 203  204     Mateo     Perez   46    male        mateo.perez@x.dummyjson.com
# 204  205    Aubrey    Garcia   29  female      aubrey.garcia@x.dummyjson.com
# 205  206     Elena     Baker   35  female        elena.baker@x.dummyjson.com
# 206  207      Jace     Smith   42    male         jace.smith@x.dummyjson.com
# 207  208  Samantha  Martinez   28  female  samantha.martinez@x.dummyjson.com
#
#                 phone   username       password   birthDate  \
# 203  +44 704-302-8113     mateop     mateoppass   1979-1-26
# 204   +1 470-576-9130    aubreyg    aubreygpass   1996-11-5
# 205  +49 978-346-6960     elenab     elenabpass   1990-3-16
# 206   +1 634-923-7779      jaces      jacespass  1983-12-18
# 207  +49 493-402-2473  samanthal  samanthalpass    1997-9-3
#
#                                         image bloodGroup  height  weight  \
# 203     https://dummyjson.com/icon/mateop/128        AB-  172.33   56.27
# 204    https://dummyjson.com/icon/aubreyg/128        AB+  192.28   85.89
# 205     https://dummyjson.com/icon/elenab/128         O+  150.62   95.55
# 206      https://dummyjson.com/icon/jaces/128         A+  185.55   59.24
# 207  https://dummyjson.com/icon/samanthal/128        AB+  164.29   55.48
#
#     eyeColor              ip         macAddress                   university  \
# 203    Brown   251.91.116.19  fc:6e:67:26:8b:ff        University of Florida
# 204    Brown   0.163.108.147  fb:ae:f9:15:24:90        Pepperdine University
# 205    Brown      85.35.8.29  83:75:b2:b6:ca:8b             Tufts University
# 206     Gray  72.202.161.214  5e:fa:19:da:b9:fc      University of Rochester
# 207    Hazel  168.48.152.139   64:d:24:41:77:b8  University of Texas--Austin
#
#          ein          ssn                                          userAgent  \
# 203  654-396  199-992-447  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 204  428-615  344-154-808  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 205  509-840  640-201-673  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 206  422-384  862-683-716  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 207  951-858  408-210-580  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
#
#      role hair.color hair.type         address.address   address.city  \
# 203  user      Black     Curly        798 Ninth Street   Jacksonville
# 204  user        Red     Curly  1221 Washington Street    Los Angeles
# 205  user      Brown  Straight        117 Maple Street  San Francisco
# 206  user      Black  Straight       1856 Tenth Street        Seattle
# 207  user      Green  Straight       1890 First Street    Los Angeles
#
#       address.state address.stateCode  address.postalCode  \
# 203           Texas                TX               12771
# 204  South Carolina                SC               78498
# 205       Tennessee                TN               40535
# 206    South Dakota                SD               60977
# 207   New Hampshire                NH               53772
#
#      address.coordinates.lat  address.coordinates.lng address.country  \
# 203                23.706655               -56.346259   United States
# 204                80.449539              -142.231527   United States
# 205                30.069731              -118.879243   United States
# 206               -64.699698               -99.677422   United States
# 207               -89.077500               -81.825967   United States
#
#     bank.cardExpire   bank.cardNumber bank.cardType bank.currency  \
# 203           03/30  6269389588713214      UnionPay           NZD
# 204           01/29  4922036660101826          Visa           NZD
# 205           01/30  5437614839810348    Mastercard           INR
# 206           05/30  6011114091979826      Discover           CNY
# 207           04/27  4729390503046994          Visa           CAD
#
#                   bank.iban    company.department  \
# 203  DE89507404827985024217           Engineering
# 204  DE91641615994664908034                 Legal
# 205  DE24112202737130790320           Engineering
# 206  DE08456467042398880704             Marketing
# 207  DE61932146076474116124  Business Development
#
#                      company.name      company.title company.address.address  \
# 203  Hickle, Altenwerth and Stamm  Software Engineer      1326 Second Street
# 204                     Moore Inc      Web Developer        240 Third Street
# 205                    Heller LLC    Project Manager    139 Jefferson Street
# 206     Quigley, Dare and Kovacek     Data Scientist      574 Madison Street
# 207              Schowalter Group    Project Manager        1046 Main Street
#
#     company.address.city company.address.state company.address.stateCode  \
# 203               Denver               Arizona                        AZ
# 204        San Francisco             Minnesota                        MN
# 205          San Antonio                 Idaho                        ID
# 206        San Francisco               Arizona                        AZ
# 207            San Diego         Massachusetts                        MA
#
#      company.address.postalCode  company.address.coordinates.lat  \
# 203                       10591                        18.569908
# 204                       58649                         3.609112
# 205                       50546                         1.356153
# 206                       19079                         2.230209
# 207                       75183                       -43.398744
#
#      company.address.coordinates.lng company.address.country crypto.coin  \
# 203                       -50.337520           United States     Bitcoin
# 204                       -35.397672           United States     Bitcoin
# 205                       175.897893           United States     Bitcoin
# 206                        84.272010           United States     Bitcoin
# 207                      -176.705236           United States     Bitcoin
#
#                                   crypto.wallet    crypto.network
# 203  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 204  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 205  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 206  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 207  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)

# %%
df.sample(10)
# Out:
#       id  firstName  lastName  age  gender                            email  \
# 27    28       Lily       Lee   30  female         lily.lee@x.dummyjson.com
# 106  107     Olivia  Anderson   30  female  olivia.anderson@x.dummyjson.com
# 156  157      Aaron      Cook   28    male       aaron.cook@x.dummyjson.com
# 144  145       Luke    Cooper   26    male      luke.cooper@x.dummyjson.com
# 45    46     Hannah  Robinson   30  female  hannah.robinson@x.dummyjson.com
# 13    14  Charlotte     Lopez   37  female  charlotte.lopez@x.dummyjson.com
# 176  177     Xavier    Wright   38    male    xavier.wright@x.dummyjson.com
# 150  151     Nathan      Reed   29    male      nathan.reed@x.dummyjson.com
# 141  142       Aria    Parker   28  female      aria.parker@x.dummyjson.com
# 86    87     Hunter    Gordon   34    male    hunter.gordon@x.dummyjson.com
#
#                 phone    username        password   birthDate  \
# 27    +1 808-757-9867       lilyb       lilybpass   1995-12-3
# 106  +44 952-688-2836     oliviah     oliviahpass   1995-6-23
# 156  +81 362-539-6973      aaronc      aaroncpass   1997-1-26
# 144  +61 347-869-6758       lukec       lukecpass   1999-4-20
# 45   +92 556-625-4398     hannahr     hannahrpass    1995-2-2
# 13   +44 373-953-5028  charlottem  charlottempass    1988-6-8
# 176  +91 561-239-9006     xavierw     xavierwpass   1987-1-11
# 150   +1 448-642-4577     nathanr     nathanrpass  1996-12-26
# 141  +91 762-847-6884       ariam       ariampass    1997-7-6
# 86    +1 986-988-5297     hunterg     huntergpass    1991-2-8
#
#                                          image bloodGroup  height  weight  \
# 27        https://dummyjson.com/icon/lilyb/128        AB-  181.42   51.49
# 106     https://dummyjson.com/icon/oliviah/128         B+  155.22   99.18
# 156      https://dummyjson.com/icon/aaronc/128        AB+  165.60   61.17
# 144       https://dummyjson.com/icon/lukec/128         O-  165.98   79.02
# 45      https://dummyjson.com/icon/hannahr/128        AB+  150.25   67.93
# 13   https://dummyjson.com/icon/charlottem/128        AB-  178.92   82.46
# 176     https://dummyjson.com/icon/xavierw/128        AB+  192.26   85.15
# 150     https://dummyjson.com/icon/nathanr/128         A+  186.76   52.22
# 141       https://dummyjson.com/icon/ariam/128        AB-  164.79   92.15
# 86      https://dummyjson.com/icon/hunterg/128         A+  186.43   83.88
#
#     eyeColor               ip         macAddress                  university  \
# 27      Gray    67.184.255.96   18:b6:c7:a:50:3f    Johns Hopkins University
# 106    Brown  209.171.160.250  a0:c1:a8:38:da:2c           Boston University
# 156    Green    71.248.65.203   9e:3f:8b:b:83:af  University of Pennsylvania
# 144    Hazel   219.83.201.134   2a:d6:6b:5:8e:22   University of Connecticut
# 45     Brown    82.201.57.248  d5:da:6d:bc:6d:1b          Harvard University
# 13     Brown    119.103.95.60  f6:ff:37:aa:6c:f1     Northeastern University
# 176   Violet  191.157.149.183  b6:25:29:40:c0:e3  Carnegie Mellon University
# 150    Amber  216.178.112.125  1b:a1:e1:cd:a2:39  University of Pennsylvania
# 141     Blue   112.164.28.147    c1:1:6a:d:86:c4         Stanford University
# 86      Blue     59.138.90.32  6f:92:45:21:c8:b3            Emory University
#
#          ein          ssn                                          userAgent  \
# 27   229-776  358-185-671  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 106  892-707  430-178-552  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 156  862-277  270-351-584  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 144  866-874  865-660-743  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:9...
# 45   449-504  150-215-129  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 13   364-782  255-491-479  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 176  480-899  571-857-220  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 150  647-669  355-857-184  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 141  385-819  889-374-959  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 86   688-971  787-117-328  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
#
#           role hair.color hair.type     address.address  address.city  \
# 27        user     Purple  Straight     1946 Oak Street       Phoenix
# 106       user       Blue      Wavy    466 Cedar Street       Houston
# 156       user       Blue     Curly    169 First Street       Phoenix
# 144       user     Blonde      Wavy    355 Ninth Street   San Antonio
# 45        user      Green     Kinky   666 Fourth Street       Phoenix
# 13   moderator       Gray     Kinky   208 Second Street      Columbus
# 176       user      Green  Straight  1497 Eighth Street  Jacksonville
# 150       user      Brown     Curly     82 Cedar Street   Los Angeles
# 141       user      Green     Curly   1504 Tenth Street       Phoenix
# 86        user        Red     Curly    614 Third Street     Charlotte
#
#      address.state address.stateCode  address.postalCode  \
# 27   Massachusetts                MA               41540
# 106        Vermont                VT               37773
# 156        Wyoming                WY               52331
# 144       Maryland                MD               36126
# 45   West Virginia                WV               82463
# 13            Ohio                OH               42044
# 176       Maryland                MD               37262
# 150           Utah                UT               73204
# 141        Alabama                AL               16573
# 86         Florida                FL               77521
#
#      address.coordinates.lat  address.coordinates.lng address.country  \
# 27                 -9.870590               -72.336845   United States
# 106               -41.687661               162.818710   United States
# 156                -6.538887               -58.475605   United States
# 144               -39.478613              -164.971685   United States
# 45                  3.841810               -33.501862   United States
# 13                -44.443762              -151.420561   United States
# 176               -82.732098              -118.759483   United States
# 150                66.874876               -47.038037   United States
# 141                56.943768                41.212736   United States
# 86                 72.687425               145.404561   United States
#
#     bank.cardExpire   bank.cardNumber              bank.cardType  \
# 27            12/28  5551782139834613                 Mastercard
# 106           05/29  5352159445468371                 Mastercard
# 156           03/29  6011771715186854                   Discover
# 144           05/30  6280401969910585                   UnionPay
# 45            06/30  6011824282761474                   Discover
# 13            12/27  3634388457177035  Diners Club International
# 176           08/30  6206898893365896                   UnionPay
# 150           04/27  6249029371283109                   UnionPay
# 141           09/27  6011811630030256                   Discover
# 86            04/27  6011958188897220                   Discover
#
#     bank.currency               bank.iban  company.department  \
# 27            CAD  DE49484285539189712621  Product Management
# 106           PKR  DE17571141744410142594               Legal
# 156           AUD  DE28971190963043337518             Support
# 144           JPY  DE83804394975915686542           Marketing
# 45            USD  DE13885235068199673116         Engineering
# 13            PKR  DE54092147842698685963          Accounting
# 176           INR  DE84969044320419430591     Human Resources
# 150           USD  DE15115435946113309166            Training
# 141           INR  DE52636264791885715598     Human Resources
# 86            USD  DE05114187235425829622             Support
#
#                           company.name               company.title  \
# 27                          Cremin Inc  Quality Assurance Engineer
# 106                      Okuneva Group                    Engineer
# 156        Leffler, Rolfson and Becker          Support Specialist
# 144                   Kreiger and Sons   Chief Information Officer
# 45                           Weber Inc  Technical Support Engineer
# 13                     Zulauf and Sons     Chief Executive Officer
# 176                          Kling Inc           Marketing Manager
# 150                        Stark Group     Chief Operating Officer
# 141  Oberbrunner, Mosciski and Witting          Software Architect
# 86                      Stark and Sons   Chief Information Officer
#
#     company.address.address company.address.city company.address.state  \
# 27        1735 Cedar Street              Phoenix               Wyoming
# 106       1466 Third Street          Los Angeles             Minnesota
# 156        380 Maple Street          San Antonio              Michigan
# 144        208 Ninth Street               Dallas          Rhode Island
# 45       1654 Second Street         Indianapolis              Missouri
# 13     569 Jefferson Street          Los Angeles               Montana
# 176     1643 Madison Street              Chicago         West Virginia
# 150       1075 Adams Street         Philadelphia        North Carolina
# 141       1103 Maple Street          Los Angeles              Kentucky
# 86         969 Fifth Street              Houston          Rhode Island
#
#     company.address.stateCode  company.address.postalCode  \
# 27                         WY                       85797
# 106                        MN                       26033
# 156                        MI                       44238
# 144                        RI                       78375
# 45                         MO                       84519
# 13                         MT                       17779
# 176                        WV                       24314
# 150                        NC                       28999
# 141                        KY                       37560
# 86                         RI                       41055
#
#      company.address.coordinates.lat  company.address.coordinates.lng  \
# 27                         72.231441                      -158.147245
# 106                        74.988123                        14.189715
# 156                       -31.851481                       -63.253251
# 144                        32.293798                       -24.546543
# 45                        -69.657286                        97.241416
# 13                        -18.371256                        22.566258
# 176                         6.085107                      -113.724523
# 150                        55.767346                       -60.983019
# 141                        -5.555558                        -6.162671
# 86                        -66.563922                       158.379537
#
#     company.address.country crypto.coin  \
# 27            United States     Bitcoin
# 106           United States     Bitcoin
# 156           United States     Bitcoin
# 144           United States     Bitcoin
# 45            United States     Bitcoin
# 13            United States     Bitcoin
# 176           United States     Bitcoin
# 150           United States     Bitcoin
# 141           United States     Bitcoin
# 86            United States     Bitcoin
#
#                                   crypto.wallet    crypto.network
# 27   0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 106  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 156  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 144  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 45   0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 13   0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 176  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 150  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 141  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 86   0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)

# %%
df[["age", "height", "weight"]].isnull().sum()
# Out:
# age       0
# height    0
# weight    0
# dtype: int64

# %%
df["age"].fillna(df["age"].median(), inplace=True)
df["height"].fillna(df["height"].median(), inplace=True)
df["weight"].fillna(df["weight"].median(), inplace=True)
# Out:
# /tmp/ipython-input-3554161558.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["age"].fillna(df["age"].median(), inplace=True)
# /tmp/ipython-input-3554161558.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["height"].fillna(df["height"].median(), inplace=True)
# /tmp/ipython-input-3554161558.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["weight"].fillna(df["weight"].median(), inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
plt.figure()
sns.histplot(df["age"], kde=True)
plt.title(" average age of users")
plt.show()
# avg of ages --> from 30 to 35

# %%
plt.figure()
sns.barplot(x="gender", y="age", data=df)
plt.title("Average Age by Gender")
plt.show()
# avg age by gender --> male --> 35     , female --> 30 to 33

# %%
plt.figure()
sns.countplot(x="gender", data=df)
plt.title("Users per Gender")
plt.show()

# users per genders: male > female

# %%
plt.figure(figsize=(10,5))
sns.countplot(y="address.city",
              data=df,
              order=df["address.city"].value_counts().head(10).index)
plt.title("Top 10 Cities")
plt.show()

# %%
avg_height_weight = df[["height", "weight"]].mean()

print("Average Height:", avg_height_weight["height"])
print("Average Weight:", avg_height_weight["weight"])
# Out:
# Average Height: 175.72024038461538
# Average Weight: 75.03860576923077

# %%
plt.figure()
sns.histplot(df["height"], kde=True)
plt.title("Height Distribution")
plt.xlabel("Height")
plt.ylabel("Count")

plt.figure()
sns.histplot(df["weight"], kde=True)
plt.title("Weight Distribution")
plt.xlabel("Weight")
plt.ylabel("Count")
plt.show()

# Based on correlation values and scatter plots, there is no strong relationship between age and height or weight. The correlation coefficients are close to zero, indicating weak or no linear relationship
